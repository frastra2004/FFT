# %%
from convolution_function import convolution
from fft_function import Fourier_transform
from fft_graph_function import Fourier_transform_graphs
import numpy as np
from numpy.fft import fft, rfft
import matplotlib.pyplot as plt
f=np.zeros(250)
f[100:150]=1/50

# %%
Fourier_transform_graphs(f)

# %%
convolution(f,f)
# Out:
# /Users/francescostraniero/Documents/Pembroke 2nd year/Labs/CO32/convolution_function.py:24: ComplexWarning: Casting complex values to real discards the imaginary part
#   ifth[0:l] = ifft(fth, n = l)
# /Users/francescostraniero/Documents/Pembroke 2nd year/Labs/CO32/convolution_function.py:25: ComplexWarning: Casting complex values to real discards the imaginary part
#   ifth[l:dl] = np.flip(ifft(fth, n = l))
